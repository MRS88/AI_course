# %% [markdown]
# <a href="https://colab.research.google.com/github/ShutTheFuckUpDonny/AI_course/blob/master/%D0%BD%D0%B5%D0%B4%D0%B5%D0%BB%D1%8F_12_%D0%9F%D0%BE%D0%BB%D0%BD%D0%BE%D1%81%D0%B2%D1%8F%D0%B7%D0%BD%D1%8B%D0%B5_%D1%81%D0%B5%D1%82%D0%B8%2C_%D0%BE%D0%B1%D1%83%D1%87%D0%B0%D1%8E%D1%89%D0%B0%D1%8F_%D0%B8_%D1%82%D0%B5%D1%81%D1%82%D0%BE%D0%B2%D0%B0%D1%8F_%D0%B2%D1%8B%D0%B1%D0%BE%D1%80%D0%BA%D0%B8_Light_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3. Создайте сеть следующей архитектуры:
#
# - 4 Dense слоя
# - Dropout слоя
# - BatchNormalization слоя

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def create_model():
    model = Sequential()
    model.add(Dense(800, input_dim=784, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(400, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def create_model_2():
    model = Sequential()
    model.add(Dropout(0.3, input_dim=784))
    model.add(Dense(800, activation='relu'))
    model.add(Dense(400, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def create_model_3():
    model = Sequential()
    model.add(Dense(800, activation='relu'))
    model.add(Dropout(0.3, input_dim=784))
    model.add(BatchNormalization())
    model.add(Dense(400, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
def prepare_data():
    (x_train_org, y_train_org), (x_test_org, y_test_org) = mnist.load_data()
    x_train, x_test, y_train, y_test = train_test_split(x_train_org, y_train_org, test_size=0.2)
    x_train = x_train.reshape(48000, 784)
    x_test = x_test.reshape(12000, 784)
    x_train = x_train.astype('float32')
    x_train = x_train / 255
    x_test = x_test.astype('float32')
    x_test = x_test / 255
    y_train = utils.to_categorical(y_train, 10)
    y_test = utils.to_categorical(y_test, 10)
    return x_train, x_test, y_train, y_test

# %%
def fit_model():
    model = create_model()
    x_train, x_test, y_train, y_test = prepare_data()
    print(x_train.shape, y_train.shape)
    history = model.fit(x_train, y_train, batch_size=128, epochs=20, validation_split=0.2, verbose=1)
    print()
    scores = model.evaluate(x_test, y_test, verbose=1)
    print(scores)
    print('Доля верных ответов на тестовых данных: ', round(scores[1]*100, 2), '%', sep='')
    print()
    val_acc = round(history.history['val_accuracy'][-1], 4) * 100 # точность на последней эпохе тестовой выборки
    key_val = 'Точность проверочной выборки модели №1'
    value_val = str(val_acc) + '%'
    key_test = 'Точность на тестовых данных модели №1'
    value_test = str(round(scores[1] * 100, 2)) + '%'
    d = {}
    d[key_val] = value_val
    d[key_test] = value_test
    return d

def fit_model_2():
    model = create_model_2()
    x_train, x_test, y_train, y_test = prepare_data()
    print(x_train.shape, y_train.shape)
    history = model.fit(x_train, y_train, batch_size=128, epochs=20, validation_split=0.2, verbose=1)
    print()
    scores = model.evaluate(x_test, y_test, verbose=1)
    print(scores)
    print('Доля верных ответов на тестовых данных: ', round(scores[1]*100, 2), '%', sep='')
    print()
    val_acc = round(history.history['val_accuracy'][-1], 4) * 100 # точность на последней эпохе тестовой выборки
    key_val = 'Точность проверочной выборки модели №2'
    value_val = str(val_acc) + '%'
    key_test = 'Точность на тестовых данных модели №2'
    value_test = str(round(scores[1] * 100, 2)) + '%'
    d = {}
    d[key_val] = value_val
    d[key_test] = value_test
    return d

def fit_model_3():
    model = create_model_3()
    x_train, x_test, y_train, y_test = prepare_data()
    print(x_train.shape, y_train.shape)
    history = model.fit(x_train, y_train, batch_size=128, epochs=20, validation_split=0.2, verbose=1)
    print()
    scores = model.evaluate(x_test, y_test, verbose=1)
    print(scores)
    print('Доля верных ответов на тестовых данных: ', round(scores[1]*100, 2), '%', sep='')
    print()
    val_acc = round(history.history['val_accuracy'][-1], 4) * 100 # точность на последней эпохе тестовой выборки
    key_val = 'Точность проверочной выборки модели №3'
    value_val = str(val_acc) + '%'
    key_test = 'Точность на тестовых данных модели №3'
    value_test = str(round(scores[1] * 100, 2)) + '%'
    d = {}
    d[key_val] = value_val
    d[key_test] = value_test
    return d

# %%
list_1, list_2, list_3 = [], [], []
list_1.append(fit_model())
list_2.append(fit_model_2())
list_3.append(fit_model_3())
# выводим сравнительные результаты для каждой модели на последней эпохе     
for i in [list_1, list_2, list_3]:
    print(i)
# Out:
# (48000, 784) (48000, 10)
# Epoch 1/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.2694 - accuracy: 0.9165 - val_loss: 0.1405 - val_accuracy: 0.9585
# Epoch 2/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1212 - accuracy: 0.9620 - val_loss: 0.1163 - val_accuracy: 0.9653
# Epoch 3/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0915 - accuracy: 0.9705 - val_loss: 0.0953 - val_accuracy: 0.9703
# Epoch 4/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0737 - accuracy: 0.9760 - val_loss: 0.0978 - val_accuracy: 0.9677
# Epoch 5/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0606 - accuracy: 0.9800 - val_loss: 0.0856 - val_accuracy: 0.9735
# Epoch 6/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0512 - accuracy: 0.9831 - val_loss: 0.0846 - val_accuracy: 0.9741
# Epoch 7/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0436 - accuracy: 0.9854 - val_loss: 0.0867 - val_accuracy: 0.9749
# Epoch 8/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0424 - accuracy: 0.9859 - val_loss: 0.0948 - val_accuracy: 0.9729
# Epoch 9/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0385 - accuracy: 0.9866 - val_loss: 0.0799 - val_accuracy: 0.9779
# Epoch 10/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0294 - accuracy: 0.9897 - val_loss: 0.0878 - val_accuracy: 0.9781
# Epoch 11/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0318 - accuracy: 0.9890 - val_loss: 0.0949 - val_accuracy: 0.9755
# Epoch 12/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0313 - accuracy: 0.9894 - val_loss: 0.0909 - val_accuracy: 0.9760
# Epoch 13/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.0913 - val_accuracy: 0.9771
# Epoch 14/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0304 - accuracy: 0.9897 - val_loss: 0.1078 - val_accuracy: 0.9741
# Epoch 15/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0234 - accuracy: 0.9920 - val_loss: 0.0767 - val_accuracy: 0.9800
# Epoch 16/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.0887 - val_accuracy: 0.9787
# Epoch 17/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0244 - accuracy: 0.9917 - val_loss: 0.1017 - val_accuracy: 0.9769
# Epoch 18/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0236 - accuracy: 0.9920 - val_loss: 0.0952 - val_accuracy: 0.9784
# Epoch 19/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0199 - accuracy: 0.9938 - val_loss: 0.0962 - val_accuracy: 0.9787
# Epoch 20/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0188 - accuracy: 0.9936 - val_loss: 0.0938 - val_accuracy: 0.9786
#
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0916 - accuracy: 0.9801
# [0.09162268042564392, 0.9800833463668823]
# Доля верных ответов на тестовых данных: 98.01%
#
# (48000, 784) (48000, 10)
# Epoch 1/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.3209 - accuracy: 0.9024 - val_loss: 0.1335 - val_accuracy: 0.9623
# Epoch 2/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1516 - accuracy: 0.9538 - val_loss: 0.1133 - val_accuracy: 0.9664
# Epoch 3/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1155 - accuracy: 0.9629 - val_loss: 0.0947 - val_accuracy: 0.9709
# Epoch 4/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0929 - accuracy: 0.9699 - val_loss: 0.0840 - val_accuracy: 0.9740
# Epoch 5/20
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0765 - accuracy: 0.9757 - val_loss: 0.0767 - val_accuracy: 0.9740
# Epoch 6/20
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0700 - accuracy: 0.9770 - val_loss: 0.0735 - val_accuracy: 0.9758
# Epoch 7/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0615 - accuracy: 0.9800 - val_loss: 0.0663 - val_accuracy: 0.9792
# Epoch 8/20
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0583 - accuracy: 0.9808 - val_loss: 0.0622 - val_accuracy: 0.9816
# Epoch 9/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0497 - accuracy: 0.9834 - val_loss: 0.0654 - val_accuracy: 0.9794
# Epoch 10/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0466 - accuracy: 0.9840 - val_loss: 0.0704 - val_accuracy: 0.9781
# Epoch 11/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0422 - accuracy: 0.9863 - val_loss: 0.0649 - val_accuracy: 0.9806
# Epoch 12/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0426 - accuracy: 0.9861 - val_loss: 0.0681 - val_accuracy: 0.9802
# Epoch 13/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0388 - accuracy: 0.9870 - val_loss: 0.0671 - val_accuracy: 0.9792
# Epoch 14/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0331 - accuracy: 0.9888 - val_loss: 0.0618 - val_accuracy: 0.9823
# Epoch 15/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0357 - accuracy: 0.9881 - val_loss: 0.0604 - val_accuracy: 0.9824
# Epoch 16/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0349 - accuracy: 0.9883 - val_loss: 0.0657 - val_accuracy: 0.9802
# Epoch 17/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0310 - accuracy: 0.9899 - val_loss: 0.0638 - val_accuracy: 0.9810
# Epoch 18/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0297 - accuracy: 0.9902 - val_loss: 0.0746 - val_accuracy: 0.9804
# Epoch 19/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0261 - accuracy: 0.9912 - val_loss: 0.0735 - val_accuracy: 0.9807
# Epoch 20/20
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0254 - accuracy: 0.9911 - val_loss: 0.0680 - val_accuracy: 0.9825
#
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0790 - accuracy: 0.9803
# [0.07904686778783798, 0.9802500009536743]
# Доля верных ответов на тестовых данных: 98.03%
#
# (48000, 784) (48000, 10)
# Epoch 1/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.2523 - accuracy: 0.9218 - val_loss: 0.1384 - val_accuracy: 0.9598
# Epoch 2/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.1167 - accuracy: 0.9629 - val_loss: 0.0914 - val_accuracy: 0.9715
# Epoch 3/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0929 - accuracy: 0.9706 - val_loss: 0.1098 - val_accuracy: 0.9660
# Epoch 4/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0795 - accuracy: 0.9740 - val_loss: 0.0834 - val_accuracy: 0.9736
# Epoch 5/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0659 - accuracy: 0.9787 - val_loss: 0.0786 - val_accuracy: 0.9764
# Epoch 6/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0568 - accuracy: 0.9807 - val_loss: 0.0763 - val_accuracy: 0.9774
# Epoch 7/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0506 - accuracy: 0.9833 - val_loss: 0.0760 - val_accuracy: 0.9776
# Epoch 8/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0456 - accuracy: 0.9850 - val_loss: 0.0893 - val_accuracy: 0.9735
# Epoch 9/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0429 - accuracy: 0.9854 - val_loss: 0.0818 - val_accuracy: 0.9772
# Epoch 10/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0435 - accuracy: 0.9856 - val_loss: 0.0884 - val_accuracy: 0.9765
# Epoch 11/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0393 - accuracy: 0.9871 - val_loss: 0.0797 - val_accuracy: 0.9778
# Epoch 12/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0346 - accuracy: 0.9885 - val_loss: 0.0750 - val_accuracy: 0.9795
# Epoch 13/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0356 - accuracy: 0.9880 - val_loss: 0.0918 - val_accuracy: 0.9736
# Epoch 14/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0339 - accuracy: 0.9887 - val_loss: 0.0872 - val_accuracy: 0.9774
# Epoch 15/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0323 - accuracy: 0.9895 - val_loss: 0.0867 - val_accuracy: 0.9769
# Epoch 16/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0248 - accuracy: 0.9923 - val_loss: 0.0865 - val_accuracy: 0.9777
# Epoch 17/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 0.0804 - val_accuracy: 0.9811
# Epoch 18/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0322 - accuracy: 0.9891 - val_loss: 0.0756 - val_accuracy: 0.9807
# Epoch 19/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.0766 - val_accuracy: 0.9807
# Epoch 20/20
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0258 - accuracy: 0.9911 - val_loss: 0.0829 - val_accuracy: 0.9792
#
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0806 - accuracy: 0.9812
# [0.08055885136127472, 0.981249988079071]
# Доля верных ответов на тестовых данных: 98.12%
#
# [{'Точность проверочной выборки модели №1': '97.86%', 'Точность на тестовых данных модели №1': '98.01%'}]
# [{'Точность проверочной выборки модели №2': '98.25%', 'Точность на тестовых данных модели №2': '98.03%'}]
# [{'Точность проверочной выборки модели №3': '97.92%', 'Точность на тестовых данных модели №3': '98.12%'}]

# %% [markdown]
# Вывод.
# Результат показал, что при данной архитектуры нейронной сети точность на тестовой выборки выше точности на проверочной выборке.
# Слои Dropout и BatchNormalization повлияли на переобучение и точность на проверочной выборке соответственно.
