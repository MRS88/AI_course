# %% [markdown]
# <a href="https://colab.research.google.com/github/MRS88/AI_course/blob/master/%D0%BD%D0%B5%D0%B4%D0%B5%D0%BB%D1%8F_05_Matplotlib_%D0%B8_Seaborn/Ultra_light.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание по Matplotlib и Seaborn
# # Ultra light
# ### *Часть 1. Matplotlib*

# %% [markdown]
# Импортируем библиотеки matplotlib и seaborn

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### **Задача 1**
#
# На основе данных x и y, представленных ниже, постройте 2 графика plot и scatter на разных плоскостях.

# %%
# Данные для построения графика
x = [-7, -5, 7, 9, 10, 10, 9, -7, 0, 5, 7, 4, 0, 6, 8, 4, 0]
y = [0, 2, 2, 5, 5, 1, 0, 0, 2, 6, 6, 2, 1, -3, -3, 1, 1]

# %% [markdown]
# ### **Решение:**

# %%
plt.plot(x, y)
plt.show()
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### **Задача 2**
#
# Добавьте на предыдущий график plot линии сетки, подписи осей х и y, название графика "Самолет". Сделайте размер графика (6, 3).

# %% [markdown]
# ### **Решение:**

# %%
plt.figure(figsize=(6, 3))
plt.grid()
plt.plot(x, y)
plt.title('Самолет')
plt.xlabel('Ось X')
plt.ylabel('Ось Y')
plt.show()

# %% [markdown]
# ### **Задача 3**
#
# Постройте, на основе приведенного ниже словаря, диаграмму. Ключи словаря будут подписями на оси х.

# %%
# Данные для построения диаграммы
data = {'Яблоки': 10, 'Апельсины': 15, 'Лимоны': 5, 'Лайм': 20}
names = list(data.keys())
values = list(data.values())

# %% [markdown]
# ### **Решение:**

# %%
plt.bar(names, values, color='g')
plt.show()

# %% [markdown]
# ### *Часть 2. Seaborn*

# %% [markdown]
# ### **Задача 4**
#
# Постройте boxplot на основе списка spis, приведенного ниже. Измените цвет графика на зеленый.

# %%
# Список значений
spis = [2, 4, 1, 5, 6, 13]

# %% [markdown]
# ### **Решение:**

# %%
sns.boxplot(data=spis, palette=sns.color_palette('Greens_r'), orient='h')
plt.show()

# %% [markdown]
# ### **Задача 5**
#
# Постройте график lmplot на основе датафрейма, приведенного ниже (строить нужно по данным столбца 'x' и 'y').

# %%
# Подгружаем датасет "anscombe"
df = sns.load_dataset("anscombe")

# Выводим первые 5 строк датасета
df.head(5)
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %% [markdown]
# ### **Решение:**

# %%
sns.lmplot(data=df, x=df.columns[1], y=df.columns[2])
plt.grid()
plt.show()
