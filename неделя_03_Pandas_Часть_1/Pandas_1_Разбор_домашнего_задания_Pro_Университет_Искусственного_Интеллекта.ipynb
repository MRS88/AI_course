# %% [markdown]
# <a href="https://colab.research.google.com/github/MRS88/AI_course/blob/master/%D0%BD%D0%B5%D0%B4%D0%B5%D0%BB%D1%8F_03_Pandas_%D0%A7%D0%B0%D1%81%D1%82%D1%8C_1/Pandas_1_%D0%A0%D0%B0%D0%B7%D0%B1%D0%BE%D1%80_%D0%B4%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B3%D0%BE_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D1%8F_Pro_%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82_%D0%98%D1%81%D0%BA%D1%83%D1%81%D1%81%D1%82%D0%B2%D0%B5%D0%BD%D0%BD%D0%BE%D0%B3%D0%BE_%D0%98%D0%BD%D1%82%D0%B5%D0%BB%D0%BB%D0%B5%D0%BA%D1%82%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #Импортируем библиотеку numpy
import pandas as pd #Импортируем библиотеку pandas

# %% [markdown]
# ### Задача 1
#
# Используя соответствующую функцию библиотеки Pandas, подгрузите датасет из файла 'train.csv'.
#
# Выведите на экран первые 5 строк датафрейма (метод head).
#
# В качестве индексов датафрейма укажите нулевой столбец.

# %% [markdown]
# **Решение:**

# %%
#Подключаем Google Диск
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Базы/train (1).csv', index_col=0) # Загружаем файл train.csv в ДатаФрейм, указывая нулевой столбец в качестве индексов
df.head() # Выводим первые 5 строк сформированного ДатаФрейма
# Out:
#     MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# Id                                    ...
# 1           60       RL         65.0  ...        WD        Normal    208500
# 2           20       RL         80.0  ...        WD        Normal    181500
# 3           60       RL         68.0  ...        WD        Normal    223500
# 4           70       RL         60.0  ...        WD       Abnorml    140000
# 5           60       RL         84.0  ...        WD        Normal    250000
#
# [5 rows x 80 columns]

# %% [markdown]
# ### Задача 2
#
# Для подгруженного из предыдущей задачи датасета выполните следующее:
# * посчитайте, сколько всего записей,
# * определите тип данных в каждом столбце,
# * проверьте, есть ли пропуски,
# * выведите на экран описательные статистики.
#
# P.S. Используйте соответствующие встроенные методы.

# %% [markdown]
# **Решение:**

# %%
print('Всего строк:', df.shape[0])
print('Всего записей в ДатаФрейме:',df.size)
# Out:
# Всего строк: 1460
# Всего записей в ДатаФрейме: 116800

# %%
df.info() # Выводим тип данных каждого столбца
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df.isna().sum() # Выводим количество пропусков в каждом столбце
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %%
df.describe() # Выводим описательные статистики
# Out:
#         MSSubClass  LotFrontage  ...       YrSold      SalePrice
# count  1460.000000  1201.000000  ...  1460.000000    1460.000000
# mean     56.897260    70.049958  ...  2007.815753  180921.195890
# std      42.300571    24.284752  ...     1.328095   79442.502883
# min      20.000000    21.000000  ...  2006.000000   34900.000000
# 25%      20.000000    59.000000  ...  2007.000000  129975.000000
# 50%      50.000000    69.000000  ...  2008.000000  163000.000000
# 75%      70.000000    80.000000  ...  2009.000000  214000.000000
# max     190.000000   313.000000  ...  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ### Задача 3
#
# Используя соответствующий встроенный метод, дропните, т. е. удалите из нашей таблички все столбцы, у которых количество пропущенных значений больше 200.
#
# * Найдите все такие столбцы (метод .isna() + подвыборка с условием).
# * Определите их названия.
# * Дропните их (используйте метод .drop(имена столбцов)).
# * Результат сохраните в новой табличке data_1, исходную менять не нужно.
#
# Могут быть полезны следующие параметры и методы:
#
# *   columns - названия столбцов датафрейма
# *   df[условие] - подвыборка элементов по условию
# *   .drop - удаление строк или столбцов (в зависимости от параметра axis)

# %% [markdown]
# **Решение:**

# %%
df.columns # Список названий столбцов
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
columns_for_drop = df.columns[df.isna().sum() > 200] # Находим все столбцы, в которых больше 200 пропусков
print(columns_for_drop) # Отображаем найденные столбцы
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
data_1 = df.drop(columns_for_drop, axis = 1) # Удаляем столбцы
print ('Shape исходного датафрейма:', df.shape) # Отображаем размерность исходного ДатаФрейма
print ('Shape датафрейма с удаленными столбцами: ', data_1.shape) # Отображаем размерность Датафрейма с удаленными столбцами
# Out:
# Shape исходного датафрейма: (1460, 80)
# Shape датафрейма с удаленными столбцами:  (1460, 74)

# %% [markdown]
# ### Задача 4
#
# Данные, с которыми мы работаем в этом домашнем задании, содержат информацию о проданных домах. Используя датафрейм из предыдущей задачи (data_1), найдите все дома, проданные в 2007 году, у которых цена продажи выше 300000 и есть бассейн. Для подвыборки с указанными условиями сначала создайте маску:
#
# * цена продажи SalePrice
# * год продажи YrSold
# * наличие бассейна можно определить по столбцу PoolArea

# %% [markdown]
# **Решение:**

# %%
mask = (data_1.SalePrice > 300000) & (data_1.YrSold == 2007) & (data_1.PoolArea > 0) # Формируем маску
data_1[mask] # Выводим найденные значения
# Out:
#       MSSubClass MSZoning  LotArea  ... SaleType SaleCondition SalePrice
# Id                                  ...
# 1183          60       RL    15623  ...       WD       Abnorml    745000
#
# [1 rows x 74 columns]

# %% [markdown]
# ### Задача 5
#
# Добавьте к табличке data_1 новый столбец с названием 'Flag'. Присвойте ему значения 0 или 1 в случайном порядке. Для этого
#
# * создайте одномерный массив из случайных целых чисел 0 или 1
# * размер массива должен соответствовать количеству наблюдений в датафрейме data_1
# * создайте новый столбец и присвойте ему значения одномерного массива

# %% [markdown]
# **Решение:**

# %%
rnd_array = np.random.randint(0, 2, data_1.shape[0]) # Создаем массив из 0 и 1 и размером, равным количеству строк в data_1
print ('Размер сформированного массива: ', rnd_array.shape) # Выводим размерность сформированного массива
print ('Размерность Датафрейма до добавления столбца: ', data_1.shape) # Выводим размерность ДатаФрейма
data_1['Flag'] = rnd_array # Добавляем новый столбец
print ('Размерность Датафрейма: ', data_1.shape) # Выводим размерность ДатаФрейма
data_1.head(10) # Выводим 10 строк ДатаФрейма
# Out:
# Размер сформированного массива:  (1460,)
# Размерность Датафрейма до добавления столбца:  (1460, 74)
# Размерность Датафрейма:  (1460, 75)
#     MSSubClass MSZoning  LotArea Street  ... SaleType SaleCondition SalePrice Flag
# Id                                       ...
# 1           60       RL     8450   Pave  ...       WD        Normal    208500    0
# 2           20       RL     9600   Pave  ...       WD        Normal    181500    0
# 3           60       RL    11250   Pave  ...       WD        Normal    223500    1
# 4           70       RL     9550   Pave  ...       WD       Abnorml    140000    0
# 5           60       RL    14260   Pave  ...       WD        Normal    250000    0
# 6           50       RL    14115   Pave  ...       WD        Normal    143000    0
# 7           20       RL    10084   Pave  ...       WD        Normal    307000    0
# 8           60       RL    10382   Pave  ...       WD        Normal    200000    0
# ...
