# %% [markdown]
# <a href="https://colab.research.google.com/github/MRS88/AI_course/blob/master/%D0%BD%D0%B5%D0%B4%D0%B5%D0%BB%D1%8F_04_Pandas_%D0%A7%D0%B0%D1%81%D1%82%D1%8C_2/Pandas_2_%D0%A0%D0%B0%D0%B7%D0%B1%D0%BE%D1%80_%D0%B4%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B3%D0%BE_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D1%8F_Pro_%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82_%D0%98%D1%81%D0%BA%D1%83%D1%81%D1%81%D1%82%D0%B2%D0%B5%D0%BD%D0%BD%D0%BE%D0%B3%D0%BE_%D0%98%D0%BD%D1%82%D0%B5%D0%BB%D0%BB%D0%B5%D0%BA%D1%82%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Задача 1. DateTime index
#
# * Подгрузите данные 'data.csv' (возможно, придется указать кодировку encoding сp1250) в переменную data.
# * Преобразуйте колонку InvoiceDate в DateTime index.
# * Удалите колонку InvoiceDate.

# %% [markdown]
# **Решение:**

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/My Drive/Базы/data.csv', encoding='cp1250') # Загружаем данные из файла data.csv
data.index = pd.to_datetime(data.InvoiceDate) # Преобразуем колонку InvoiceDate к типу DateTime
data.head() # Выводим первые 5 строк ДатаФрейма data
# Out:
#                     InvoiceNo StockCode  ... CustomerID         Country
# InvoiceDate                              ...
# 2010-12-01 08:26:00    536365    85123A  ...    17850.0  United Kingdom
# 2010-12-01 08:26:00    536365     71053  ...    17850.0  United Kingdom
# 2010-12-01 08:26:00    536365    84406B  ...    17850.0  United Kingdom
# 2010-12-01 08:26:00    536365    84029G  ...    17850.0  United Kingdom
# 2010-12-01 08:26:00    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
data.drop('InvoiceDate', axis=1, inplace=True) # Удаляем столбец InvoiceDate
data.head() # Выводим первые 5 строк ДатаФрейма
# Out:
#                     InvoiceNo StockCode  ... CustomerID         Country
# InvoiceDate                              ...
# 2010-12-01 08:26:00    536365    85123A  ...    17850.0  United Kingdom
# 2010-12-01 08:26:00    536365     71053  ...    17850.0  United Kingdom
# 2010-12-01 08:26:00    536365    84406B  ...    17850.0  United Kingdom
# 2010-12-01 08:26:00    536365    84029G  ...    17850.0  United Kingdom
# 2010-12-01 08:26:00    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Задача 2
#
# Используя датафрейм data, выберите все заказы, совершенные за период 7 декабря 2010 года с часа дня до часа и одной минуты.

# %% [markdown]
# **Решение:**

# %%
data['2010-12-07 13:00:00':'2010-12-07 13:01:00'] # Задаем интервал и выводим данные
# Out:
#                     InvoiceNo StockCode  ... CustomerID         Country
# InvoiceDate                              ...
# 2010-12-07 13:01:00    537604     84991  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     21845  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     21534  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     21527  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     21528  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     21843  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     22429  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     22551  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     22557  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     22555  ...    13488.0  United Kingdom
# 2010-12-07 13:01:00    537604     22304  ...    13488.0  United Kingdom
# ...

# %% [markdown]
# ### Задача 3
#
# По той же рабочей табличке
# * посчитайте количество уникальных наименований товаров (Description), которые купили за весь период (т. е. по всем данным). Используйте соответствующий метод.
# * найдите все уникальные страны, в которых были размещены заказы.

# %% [markdown]
# **Решение:**

# %%
print('Количество уникальных наименований товаров', data.Description.nunique()) # Выводим количество уникальных наименований товаров
data.Country.unique() # Выводим все названия стран
# Out:
# Количество уникальных наименований товаров 4223
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# ### Задача 4
#
# * Посчитайте матрицу корреляции Спирмена для наших данных.
# * Найдите 1%, 50% и 99% квантили цены за единицу товара.
#
# *Для решения данной задачи потребуется самостоятельно найти способ получения матрицы Спирмена. Обратите внимание, на вебинаре продемонстрирован пример матрицы Пирсона.*

# %% [markdown]
# **Решение:**

# %%
data.corr(method='spearman') # Выводим матрицу корреляции
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.385407   -0.141124
# UnitPrice  -0.385407   1.000000   -0.013255
# CustomerID -0.141124  -0.013255    1.000000

# %%
data.quantile([0.01, 0.5, 0.99]) # Отображаем квантили
# Out:
#       Quantity  UnitPrice  CustomerID
# 0.01      -2.0       0.19     12415.0
# 0.50       3.0       2.08     15152.0
# 0.99     100.0      18.00     18212.0

# %% [markdown]
# ### Задача 5
#
# Найдите количество клиентов, которые оформляли заказ в понедельники. Для этого
# * сделайте подвыборку, соответствующую условию "в понедельник",
# * посчитайте количество уникальных ID клиентов.
#
# *Для решения этой задачи потребуется использовать параметр индекса weekday (по аналогии с рассмотренными на вебинаре примерами .index.month, .index.day)*.

# %% [markdown]
# **Решение:**

# %%
data.CustomerID[data.index.weekday == 0].nunique() # Считаем количество уникальных пользователей (.nunique()), сделавших заказ в понедельник (weekday == 0)
# Out:
# 1769
