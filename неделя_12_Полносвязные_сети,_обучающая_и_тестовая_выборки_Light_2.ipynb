# %% [markdown]
# <a href="https://colab.research.google.com/github/ShutTheFuckUpDonny/AI_course/blob/master/%D0%BD%D0%B5%D0%B4%D0%B5%D0%BB%D1%8F_12_%D0%9F%D0%BE%D0%BB%D0%BD%D0%BE%D1%81%D0%B2%D1%8F%D0%B7%D0%BD%D1%8B%D0%B5_%D1%81%D0%B5%D1%82%D0%B8%2C_%D0%BE%D0%B1%D1%83%D1%87%D0%B0%D1%8E%D1%89%D0%B0%D1%8F_%D0%B8_%D1%82%D0%B5%D1%81%D1%82%D0%BE%D0%B2%D0%B0%D1%8F_%D0%B2%D1%8B%D0%B1%D0%BE%D1%80%D0%BA%D0%B8_Light_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2. Создайте еще два варианта сети и сравните значения точности на проверочной выборке (на последней эпохе) и на тестовой выборке. Сделайте сравнительную таблицу.

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def create_model():
    model = Sequential()
    model.add(Dense(800, input_dim=784, activation='relu'))
    model.add(Dense(400, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def create_model_2():
    model = Sequential()
    model.add(Dense(800, input_dim=784, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(400, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def create_model_3():
    model = Sequential()
    model.add(Dropout(0.3, input_dim=784))
    model.add(Dense(800, activation='relu'))
    model.add(Dense(400, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
def prepare_data():
    (x_train_org, y_train_org), (x_test_org, y_test_org) = mnist.load_data()
    x_train, x_test, y_train, y_test = train_test_split(x_train_org, y_train_org, test_size=t_s)
    x_train = x_train.reshape(int(round(60000*(1-t_s), 1)), 784)
    x_test = x_test.reshape(int(60000*t_s), 784)
    x_train = x_train.astype('float32')
    x_train = x_train / 255
    x_test = x_test.astype('float32')
    x_test = x_test / 255
    y_train = utils.to_categorical(y_train, 10)
    y_test = utils.to_categorical(y_test, 10)
    return x_train, x_test, y_train, y_test

# %%
def fit_model():
    model = create_model()
    x_train, x_test, y_train, y_test = prepare_data()
    print('Обучение сети на обучающей выборке {:.2f}%'.format((1-t_s)*100))
    print(x_train.shape, y_train.shape)
    history = model.fit(x_train, y_train, batch_size=128, epochs=20, validation_split=0.2, verbose=1)
    print()
    scores = model.evaluate(x_test, y_test, verbose=1)
    print(scores)
    print('Доля верных ответов на тестовых данных: ', round(scores[1]*100, 2), '%', sep='')
    print()
    val_acc = round(history.history['val_accuracy'][-1], 4) * 100 # точность на последней эпохе тестовой выборки
    key_val = 'Точность проверочной выборки из ' + str(int(round((1-t_s)*60000, 1))) + ' примеров'
    value_val = str(val_acc) + '%'
    key_test = 'Точность на тестовых данных из ' + str(int(t_s*60000)) + ' примеров'
    value_test = str(round(scores[1] * 100, 2)) + '%'
    d = {}
    d[key_val] = value_val
    d[key_test] = value_test
    return d

def fit_model_2():
    model = create_model_2()
    x_train, x_test, y_train, y_test = prepare_data()
    print('Обучение сети на обучающей выборке {:.2f}%'.format((1-t_s)*100))
    print(x_train.shape, y_train.shape)
    history = model.fit(x_train, y_train, batch_size=128, epochs=20, validation_split=0.2, verbose=1)
    print()
    scores = model.evaluate(x_test, y_test, verbose=1)
    print(scores)
    print('Доля верных ответов на тестовых данных: ', round(scores[1]*100, 2), '%', sep='')
    print()
    val_acc = round(history.history['val_accuracy'][-1], 4) * 100 # точность на последней эпохе тестовой выборки
    key_val = 'Точность проверочной выборки из ' + str(int(round((1-t_s)*60000, 1))) + ' примеров'
    value_val = str(val_acc) + '%'
    key_test = 'Точность на тестовых данных из ' + str(int(t_s*60000)) + ' примеров'
    value_test = str(round(scores[1] * 100, 2)) + '%'
    d = {}
    d[key_val] = value_val
    d[key_test] = value_test
    return d

def fit_model_3():
    model = create_model_3()
    x_train, x_test, y_train, y_test = prepare_data()
    print('Обучение сети на обучающей выборке {:.2f}%'.format((1-t_s)*100))
    print(x_train.shape, y_train.shape)
    history = model.fit(x_train, y_train, batch_size=128, epochs=20, validation_split=0.2, verbose=1)
    print()
    scores = model.evaluate(x_test, y_test, verbose=1)
    print(scores)
    print('Доля верных ответов на тестовых данных: ', round(scores[1]*100, 2), '%', sep='')
    print()
    val_acc = round(history.history['val_accuracy'][-1], 4) * 100 # точность на последней эпохе тестовой выборки
    key_val = 'Точность проверочной выборки из ' + str(int(round((1-t_s)*60000, 1))) + ' примеров'
    value_val = str(val_acc) + '%'
    key_test = 'Точность на тестовых данных из ' + str(int(t_s*60000)) + ' примеров'
    value_test = str(round(scores[1] * 100, 2)) + '%'
    d = {}
    d[key_val] = value_val
    d[key_test] = value_test
    return d

# %%
list_1, list_2, list_3 = [], [], []
for t_s in (1/6, 5/6, 119/120):
    list_1.append(fit_model())
    list_2.append(fit_model_2())
    list_3.append(fit_model_3())
# выводим сравнительные результаты для каждой модели на последней эпохе     
for i in [list_1, list_2, list_3]:
    print(i)
# Out:
# Обучение сети на обучающей выборке 83.33%
# (50000, 784) (50000, 10)
# Epoch 1/20
# 313/313 [==============================] - 6s 18ms/step - loss: 0.2565 - accuracy: 0.9240 - val_loss: 0.1188 - val_accuracy: 0.9644
# Epoch 2/20
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0924 - accuracy: 0.9722 - val_loss: 0.0978 - val_accuracy: 0.9694
# Epoch 3/20
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0573 - accuracy: 0.9824 - val_loss: 0.0825 - val_accuracy: 0.9770
# Epoch 4/20
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0384 - accuracy: 0.9869 - val_loss: 0.0766 - val_accuracy: 0.9775
# Epoch 5/20
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0269 - accuracy: 0.9914 - val_loss: 0.0848 - val_accuracy: 0.9760
# Epoch 6/20
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0208 - accuracy: 0.9930 - val_loss: 0.0823 - val_accuracy: 0.9773
# Epoch 7/20
# ...

# %% [markdown]
# Вывод.
# Добавление Dropout-слоя в начале и в середине для первых двух моделей (с 50000 и 10000 проверочными выборками) улучшила точность, но избежать переобучения не получилось. Требуется пересмотреть архитектуру этих моделей и добавить дополнительные слои Dropout.
# Что же касается обучающей выборки в 500 примеров, то сравнительный результат практически не изменился и остался также неудовлетворительным.
