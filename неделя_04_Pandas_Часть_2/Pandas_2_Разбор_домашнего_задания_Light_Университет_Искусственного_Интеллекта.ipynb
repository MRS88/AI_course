# %% [markdown]
# <a href="https://colab.research.google.com/github/MRS88/AI_course/blob/master/%D0%BD%D0%B5%D0%B4%D0%B5%D0%BB%D1%8F_04_Pandas_%D0%A7%D0%B0%D1%81%D1%82%D1%8C_2/Pandas_2_%D0%A0%D0%B0%D0%B7%D0%B1%D0%BE%D1%80_%D0%B4%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B3%D0%BE_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D1%8F_Light_%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82_%D0%98%D1%81%D0%BA%D1%83%D1%81%D1%81%D1%82%D0%B2%D0%B5%D0%BD%D0%BD%D0%BE%D0%B3%D0%BE_%D0%98%D0%BD%D1%82%D0%B5%D0%BB%D0%BB%D0%B5%D0%BA%D1%82%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Задача 1
# Загрузите базу статистики по приложениям из Google Play. Определите уникальные категории приложений. В цикле найдите число приложений по каждой категории.
#
# Описание базы:
# ---------------------------------
# **App** - имя приложения
#
# **Category** - категория
#
# **Rating** - рейтинг
#
# **Reviews** - число комментариев
#
# **Size** - размер
#
# **Instals** - число установок
#
# **Type** - платное или бесплатное приложение
#
# **Content Rating** - ограничения по возрасту
#
# **Genres** - жанры
#
# **Last Updated** - последнее обновление
#
# **Current Ver** - текущая версия
#
# **Android Ver** - версия для Android
#
#
# Ссылка на базу: https://drive.google.com/file/d/1dwFUK1PxzVLSyzHjPImCw_XvTIP-llJQ/view?usp=sharing

# %% [markdown]
# **Решение:**

# %%
import pandas as pd #Импортируем библиотеку Pandas

# %%
df = pd.read_csv('googleplaystore.csv') #Загружаем таблицу

# %%
df #Смотрим, что она представляет из себя
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# ...

# %%
categories = df.Category.unique().tolist() #Получаем список уникальных значений в столбце Category

# %%
#Выводим информацию
print('Категории приложений: ')
print(categories)
# Out:
# Категории приложений:
# ['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY', 'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION', 'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE', 'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME', 'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL', 'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL', 'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER', 'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION', '1.9']

# %%
#Проходим по каждой категории
for cat in categories:
  #Делаем подвыборки и смотрим размерности подвыборок
  print('Для категории ', cat, ' ' * (20 - len(cat)), 'в базе имеется', df[df.Category == cat].shape[0], 'приложений.')
# Out:
# Для категории  ART_AND_DESIGN        в базе имеется 65 приложений.
# Для категории  AUTO_AND_VEHICLES     в базе имеется 85 приложений.
# Для категории  BEAUTY                в базе имеется 53 приложений.
# Для категории  BOOKS_AND_REFERENCE   в базе имеется 231 приложений.
# Для категории  BUSINESS              в базе имеется 460 приложений.
# Для категории  COMICS                в базе имеется 60 приложений.
# Для категории  COMMUNICATION         в базе имеется 387 приложений.
# Для категории  DATING                в базе имеется 234 приложений.
# Для категории  EDUCATION             в базе имеется 156 приложений.
# Для категории  ENTERTAINMENT         в базе имеется 149 приложений.
# Для категории  EVENTS                в базе имеется 64 приложений.
# Для категории  FINANCE               в базе имеется 366 приложений.
# Для категории  FOOD_AND_DRINK        в базе имеется 127 приложений.
# Для категории  HEALTH_AND_FITNESS    в базе имеется 341 приложений.
# ...

# %% [markdown]
# ### Задача 2
# Отсортируйте приложения по рейтингу при помощи встроенных методов Pandas.

# %% [markdown]
# **Решение:**

# %%
#Сортируем таблицу и сохраняем в новую переменную
df_sorted = df.sort_values('Rating', ascending=False)

# %%
df_sorted #Смотрим результат
# Out:
#                                            App  ...   Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame  ...           NaN
# 9511                  Ek Bander Ne Kholi Dukan  ...    4.0 and up
# 10166                     FA Player Essentials  ...  4.0.3 and up
# 7895                Dine In CT - Food Delivery  ...    4.0 and up
# 5118                          Eternal Light AG  ...  4.0.3 and up
# ...                                        ...  ...           ...
# 10824                                Cardio-FR  ...    4.4 and up
# 10825                       Naruto & Boruto FR  ...    4.0 and up
# 10831                 payermonstationnement.fr  ...    4.0 and up
# 10835                                 FR Forms  ...    4.0 and up
# 10838                   Parkinson Exercices FR  ...    2.2 and up
#
# [10841 rows x 13 columns]

# %% [markdown]
# ### Задача 3
# Оставьте в выборке только те приложения, которые имеют рейтинг в пределах от 5 до 3 (оба значения включительно).
#
# Узнайте число платных и бесплатных приложений в этом списке при помощи методов Pandas.

# %% [markdown]
# **Решение:**

# %%
#Применяем маски и сохраняем снова в отдельной переменной
df_sorted2 = df_sorted[(df_sorted.Rating <= 5) & (df_sorted.Rating >= 3)]

# %%
df_sorted2 #Смотрим результат
# Out:
#                                                     App  ...   Android Ver
# 9511                           Ek Bander Ne Kholi Dukan  ...    4.0 and up
# 10166                              FA Player Essentials  ...  4.0.3 and up
# 7895                         Dine In CT - Food Delivery  ...    4.0 and up
# 5118                                   Eternal Light AG  ...  4.0.3 and up
# 6953                     BxPort - Bitcoin Bx (Thailand)  ...    4.2 and up
# ...                                                 ...  ...           ...
# 6504                                        BN Mi Banco  ...    5.0 and up
# 9950                          Emerge EV App (eBike App)  ...    6.0 and up
# 915    Acorn TV: World-class TV from Britain and Beyond  ...    4.4 and up
# 9933                            Qserve EU MDR First Aid  ...    4.1 and up
# 5181    The Artificial Intelligence Project (A.I. Chat)  ...    2.3 and up
#
# [9079 rows x 13 columns]

# %%
print('Число платных приложений: ', df_sorted2[df_sorted2.Type == 'Paid'].shape[0])
print('Число бесплатных приложений: ', df_sorted2[df_sorted2.Type == 'Free'].shape[0])
# Out:
# Число платных приложений:  625
# Число бесплатных приложений:  8454

# %% [markdown]
# ### Задача 4

# %% [markdown]
# В измененном массиве любым способом установите индексы из целых чисел в порядке возрастания.

# %% [markdown]
# **Решение:**

# %%
#Формируем список индексов и заменяем им индексы в таблице
df_sorted2.index = [i for i in range(df_sorted2.shape[0])]

# %%
df_sorted2
# Out:
#                                                    App  ...   Android Ver
# 0                             Ek Bander Ne Kholi Dukan  ...    4.0 and up
# 1                                 FA Player Essentials  ...  4.0.3 and up
# 2                           Dine In CT - Food Delivery  ...    4.0 and up
# 3                                     Eternal Light AG  ...  4.0.3 and up
# 4                       BxPort - Bitcoin Bx (Thailand)  ...    4.2 and up
# ...                                                ...  ...           ...
# 9074                                       BN Mi Banco  ...    5.0 and up
# 9075                         Emerge EV App (eBike App)  ...    6.0 and up
# 9076  Acorn TV: World-class TV from Britain and Beyond  ...    4.4 and up
# 9077                           Qserve EU MDR First Aid  ...    4.1 and up
# 9078   The Artificial Intelligence Project (A.I. Chat)  ...    2.3 and up
#
# [9079 rows x 13 columns]

# %% [markdown]
# ### Задача 5

# %% [markdown]
# Определите процент пустых ячеек к заполненным в начальной таблице. Результат выведите в процентах с округлением до двух знаков.

# %% [markdown]
# **Решение:**

# %%
print('Процент пустых ячеек к заполненным:', round(df.isna().sum().sum() * 100 / df.size , 2), '%')
# Out:
# Процент пустых ячеек к заполненным: 1.06 %
